# %%
import numpy as np
#%matplotlib notebook
import matplotlib.pyplot as plt
from DensiTDA import landmarktools

# %% [markdown]
# # Generate a random dataset

# %%
a_1 = [2,1]
a_2 = [4,3]
a_3 = [7,10]
a_4 = [9,13]
cov = np.array([[2,1],[1,2]])

# %%
X_1 = np.random.multivariate_normal(a_1, 1 * cov, 1000)
X_2 = np.random.multivariate_normal(a_2, 0.7 * cov, 500)
X_3 = np.random.multivariate_normal(a_3, cov, 200)
X_4 = np.random.multivariate_normal(a_4, cov, 100)

X = np.concatenate((X_1, X_2, X_3, X_4), axis=0)

# %%
plt.scatter(X[:,0], X[:,1], color="blue")
plt.show()

# %% [markdown]
# # Run Max of Gaussians Landmarking Selection Algorithm

# %%
# hyperparameters
d = X.shape[1]
h = np.std(X) * (len(X)) ** (-1 / (d + 4))
A = np.ones(len(X)) / (h * len(X))
s = 0.8
candidate_landmarks = X

# %%
chosen_landmarks, powers = landmarktools.max_of_gaussians_landmarking(X, A, candidate_landmarks, h, s)
# Out:
# Initializing Distrbution over Candidate Landmark Points:
# 100%|████████████████████████████████████████| 180/180 [00:01<00:00, 163.29it/s]
# Maximizing Gaussians over Landmark Points:
# 100%|█████████████████████████████████████| 1800/1800 [00:01<00:00, 1626.98it/s]

# %% [markdown]
# # Result of Max of Gaussians

# %%
chosen_landmarks = np.array(chosen_landmarks)

plt.scatter(X[:,0], X[:,1], color="blue")
plt.scatter(chosen_landmarks[:,0], chosen_landmarks[:,1], color="orange")
plt.show()

# %%
print("Precentage of points selected: ", 100 * len(chosen_landmarks) / len(X))
# Out:
# Precentage of points selected:  5.666666666666667

# %%
landmarktools.max_of_gaussians_2D_plot(X, A, candidate_landmarks, h, s, cut_off = 0.3)
# Out:
# Initializing Distrbution over Candidate Landmark Points:
# 100%|███████████████████████████████████████████| 11/11 [00:00<00:00, 24.80it/s]
# Maximizing Gaussians over Landmark Points:
#   6%|██▌                                        | 6/102 [01:28<23:36, 14.75s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 landmarktools.max_of_gaussians_2D_plot(X, A, chosen_landmarks, h, s, cut_off = 0.3)
#
# File ~/Desktop/DensiTDA/DensiTDA/landmarktools.py:201, in max_of_gaussians_2D_plot(X, A, candidate_landmarks, h, s, cut_off)
#     199 def max_of_gaussians_2D_plot(X, A, candidate_landmarks, h, s, cut_off = 0.05):
# --> 201     chosen_landmarks, total_gaussians, powers = max_of_gaussians_landmarking_helper(X, A, candidate_landmarks, h, s)
#     203     X_min = min(X[:,0])
#     204     X_max = max(X[:,0])
#
# File ~/Desktop/DensiTDA/DensiTDA/landmarktools.py:169, in max_of_gaussians_landmarking_helper(X, A, candidate_landmarks, h, s)
#     166 k = np.argmax(f_x - f_y)
#     167 y_k = X[k]
# --> 169 b_k, g_k = GaussFit(y_k, f_x[k])
#     171 chosen_landmark_indices.append(k)
#     172 chosen_landmarks.append(y_k)
#
# File ~/Desktop/DensiTDA/DensiTDA/landmarktools.py:88, in max_of_gaussians_landmarking_helper.<locals>.GaussFit(y, c)
#      86 z = 0
#      87 for a_i, x_i in zip(A, X):
# ---> 88     z += a_i * p(y,x_i,h) * x_i
#      90 z /= c
#      92 b = c / p(z, y,h)
#
# File ~/Desktop/DensiTDA/DensiTDA/landmarktools.py:12, in p(x, y, h)
#      11 def p(x,y,h):
# ---> 12     return K(LA.norm(x - y) / h)
#
# File ~/Desktop/DensiTDA/DensiTDA/landmarktools.py:9, in K(r)
#       8 def K(r):
# ----> 9     return np.exp(-r ** 2 / 2)
#
# KeyboardInterrupt:
